# %% [markdown]
# **Uploading the csv File**

# %%
from google.colab import files #importing google.colab to upload the csv
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f0f0e58f-b860-4554-b67e-62d815e2f037" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0f0e58f-b860-4554-b67e-62d815e2f037">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Importing the CSV**

# %%
import pandas as pd #importing pandas
df = pd.read_csv('MERGED2017_18_PP.csv', low_memory=False) #importing the uploaded CSV

# %% [markdown]
# **Finding the total rows and columns**

# %%
print('Number of Rows:', len(df)) #total number of rows
print('Number of Columns:', len(df.columns)) #total number of columns
# Out:
# Number of Rows: 7112
# Number of Columns: 1986

# %% [markdown]
# **Printing the first 5 rows**

# %%
df.head(5) #first 5 rows of the dataset
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# ...

# %% [markdown]
# **Printing the last 5 rows**

# %%
df.head(-5) #first 5 columns of dataset
# Out:
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7102  48154401  4220901   42209
# 7103  48305401  4224601   42246
# 7104  48312401   108131    1081
# 7105  48312402   108161    1081
# 7106  48312403   108162    1081
#
#                                                  INSTNM              CITY  \
# 0                              Alabama A & M University            Normal
# 1                   University of Alabama at Birmingham        Birmingham
# 2                                    Amridge University        Montgomery
# 3                   University of Alabama in Huntsville        Huntsville
# 4                              Alabama State University        Montgomery
# ...                                                 ...               ...
# ...

# %% [markdown]
# **Printing 5 rows randomly**

# %%
df.sample(n=5) #displaying 5 random rows
# Out:
#       UNITID    OPEID  OPEID6                                    INSTNM  \
# 6508  488040  4244100   42441              Construction Training Center
# 4088  262466  4172500   41725  Rolf Institute of Structural Integration
# 4575  418658  3493302   34933        All-State Career School-Pittsburgh
# 429   121433  1298400   12984          Professional Institute of Beauty
# 6521  488183  4247700   42477                       Regina Webb Academy
#
#                CITY STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 6508       Columbia     SC       29209           NaN      NaN     NaN  ...
# 4088        Boulder     CO  80301-0000           NaN      NaN     NaN  ...
# 4575   West Mifflin     PA       15122           NaN      NaN     NaN  ...
# 429        El Monte     CA       91731           NaN      NaN     NaN  ...
# 6521  Bowling Green     KY  42104-4457           NaN      NaN     NaN  ...
#
#       OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN  UG12MN  G12MN  \
# ...

# %% [markdown]
# **Smaller data frame with the given 9 variables**

# %%
df2 = df[["UNITID", "INSTNM", "CITY", "STABBR", "ZIP", "ADM_RATE", "UGDS", "TUITIONFEE_IN", "MN_EARN_WNE_P10"]] #selecting the columns needed
df2
# Out:
#         UNITID                                             INSTNM  \
# 0       100654                           Alabama A & M University
# 1       100663                University of Alabama at Birmingham
# 2       100690                                 Amridge University
# 3       100706                University of Alabama in Huntsville
# 4       100724                           Alabama State University
# ...        ...                                                ...
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                  CITY STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 0              Normal     AL       35762    0.9027   4824.0         9857.0
# ...

# %% [markdown]
# # **Definition of variables**
#
#
#
# 1.   UNITID: Its an unique ID for the universities and can act a primary key.
# 2.   INSTNM: Name of the Institutions.
# 3.   CITY: City in which the University is located.
# 4.   STABBR: It denotes the State Code of the american states where the university is located.
# 5.   ZIP: Its the zipcode of the location where the university is located.
# 6.   ADM_RATE: It is the acceptance rate of the university also known as admission  rate.
# 7.   UGDS: The Utrecht Gender Dysphoria Scale (UGDS) is a validated, 12-item screening measure for both adults and adolescents used extensively in gender clinics to assess gender dysphoria. [Source](https://https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7430422/)
# 8.   TUITIONFEE_IN: It is the tuition fee of the university.
# 9.   MN_EARN_WNE_P10: This translates to the mean earnings of graduates working 10 years after entry. [Source](https://www.zippia.com/advice/junior-colleges-with-highest-earning-graduates-in-each-state/#:~:text=In%20data%2Dmining%20talk%2C%20the,accurately%20rank%20the%20junior%20colleges.)

# %% [markdown]
# **Printing first 10 and last 10 rows from the above dataframe**

# %%
df2.head(10) #displaying first 10 rows
print("")
df2.head(-10) #displaying last 10 rows
# Out:
#         UNITID                                     INSTNM           CITY  \
# 0       100654                   Alabama A & M University         Normal
# 1       100663        University of Alabama at Birmingham     Birmingham
# 2       100690                         Amridge University     Montgomery
# 3       100706        University of Alabama in Huntsville     Huntsville
# 4       100724                   Alabama State University     Montgomery
# ...        ...                                        ...            ...
# 7097  47691101  SAE Institute of Technology San Francisco     Emeryville
# 7098  48065701          Rasmussen College - Overland Park  Overland Park
# 7099  48079001     Rocky Vista University - Southern Utah          Ivins
# 7100  48092101         Designer Barber & Stylist School -     Springdale
# 7101  48133101     Sharp Edgez Barber Institute - Buffalo        Buffalo
#
#      STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# ...

# %% [markdown]
# Displaying 10 rows randomly from df2

# %%
df2.sample(n=10) #displaying 10 random rows
# Out:
#         UNITID                                             INSTNM  \
# 6714  12293101  Jesuit School of Theology of Santa Clara Unive...
# 5245    448761                        CollegeAmerica-Fort Collins
# 3647    232043                       Eastern Mennonite University
# 5447    454722               Academy of Esthetics and Cosmetology
# 946     144883                               East-West University
# 7037  44903806       Strayer University-Palm Beach Gardens Campus
# 295     114044                             Elegance International
# 7086  47503305       Relay Graduate School of Education - Houston
# 845     140331                    Chattahoochee Technical College
# 5269    449366                                  Make-up Designory
#
#                     CITY STABBR         ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  \
# 6714            Berkeley     CA       94709       NaN     NaN            NaN
# 5245        Fort Collins     CO       80525       NaN   126.0        16968.0
# ...

# %% [markdown]
# **Displaying data from the row which conatains UMBC**

# %%
df2_1 = df2[(df2['INSTNM'] =='University of Maryland-Baltimore County')]
df2_1
# Out:
#       UNITID                                   INSTNM       CITY STABBR  \
# 1478  163268  University of Maryland-Baltimore County  Baltimore     MD
#
#         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1478  21250    0.6021  11130.0        11518.0              NaN

# %% [markdown]
# **Displaying data from the row which conatains Maryland-College Park**

# %%
df2_2 = df2[(df2['INSTNM'] =='University of Maryland-College Park')]
df2_2
# Out:
#       UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1479  163286  University of Maryland-College Park  College Park     MD  20742
#
#       ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1479     0.445  29273.0        10399.0              NaN

# %% [markdown]
# **Displaying data from the row which conatains Loyola Universaity Maryland**

# %%
df2_3 = df2[(df2['INSTNM'] =='Loyola University Maryland')]
df2_3
# Out:
#       UNITID                      INSTNM       CITY STABBR         ZIP  \
# 1475  163046  Loyola University Maryland  Baltimore     MD  21210-2699
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1475    0.7528  3903.0        47560.0              NaN

# %% [markdown]
# **Displaying data from the row which conatains Johns Hopkins University**

# %%
df2_4 = df2[(df2['INSTNM'] =='Johns Hopkins University')]
df2_4
#df2.loc[[1473]] #printing the row number
# Out:
#       UNITID                    INSTNM       CITY STABBR         ZIP  \
# 1473  162928  Johns Hopkins University  Baltimore     MD  21218-2688
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1473    0.1254  5663.0        52170.0              NaN

# %% [markdown]
# **Calculating the min, max, and average in-state tution of the above four institutions.**

# %%
df2= df2[(df2['INSTNM'] =='Johns Hopkins University') | (df2['INSTNM'] =='Loyola University Maryland') | (df2['INSTNM'] =='University of Maryland-College Park') | (df2['INSTNM'] =='University of Maryland-Baltimore County')] #selecting the rows with following univeristy name to find the values asked
minimum_value =df2['TUITIONFEE_IN'].min() #finding the minimum value
print("minimum_value:" ,minimum_value)

maximum_value =df2['TUITIONFEE_IN'].max() #finding the maximum value
print("maximum_value:" ,maximum_value)

Avg_value =df2['TUITIONFEE_IN'].mean() #finding the average value
print("average_value:" ,Avg_value)
# Out:
# minimum_value: 10399.0
# maximum_value: 52170.0
# average_value: 30411.75

# %% [markdown]
# **smaller dataset further to only keep colleges from Maryland, Virgina, Washington DC, Delaware, and Pennsylvinia.**

# %%
df2 = df[["UNITID", "INSTNM", "CITY", "STABBR", "ZIP", "ADM_RATE", "UGDS", "TUITIONFEE_IN", "MN_EARN_WNE_P10"]]
df3 = df2.loc[(df2['STABBR'] =='MD') | (df2['STABBR'] =='PA') | (df2['STABBR'] == 'DC') | (df2['STABBR'] == 'VA') | (df2['STABBR'] == 'DE')] #creating a new dataframe with states Maryland, Virgina, Washington DC, Delaware, and Pennsylvinia.
df3
# Out:
#         UNITID                                             INSTNM  \
# 634     130837  Margaret H Rollins School of Nursing at Beebe ...
# 635     130873                          Dawn Career Institute LLC
# 636     130907         Delaware Technical Community College-Terry
# 637     130934                          Delaware State University
# 638     130943                             University of Delaware
# ...        ...                                                ...
# 7063  45794301   Somerset County Technology Center - Bedford Site
# 7084  47503303      Relay Graduate School of Education - Delaware
# 7089  47503308  Relay Graduate School of Education - Philadelp...
# 7094  47503313  Relay Graduate School of Education - Washingto...
# 7103  48305401             Barber School of Pittsburgh - Ambridge
#
#               CITY STABBR        ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 634          Lewes     DE      19958       NaN     59.0            NaN
# ...

# %% [markdown]
# **Saving the above Dataset**

# %%
df3.to_csv('Five_States_Colleges.csv') #saving the above dataset as csv

# %% [markdown]
# **Downloading the CSV to PC**

# %%
files.download("Five_States_Colleges.csv") #downloading the csv file
