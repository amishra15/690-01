# %%
import pandas as pd

# %% [markdown]
# ## Reading data with Python

# %%
url = 'https://raw.githubusercontent.com/amishraUMBC/690-01/main/Assignment_05/btc-market-price.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    2/4/17 0:00  1099.169125
# 0  3/4/17 0:00     1141.813
# 1  4/4/17 0:00            ?
# 2  5/4/17 0:00  1133.079314
# 3  6/4/17 0:00            -
# 4  7/4/17 0:00            -

# %%
df = pd.read_csv('https://raw.githubusercontent.com/amishraUMBC/690-01/main/Assignment_05/btc-market-price.csv', header=None)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/amishraUMBC/690-01/main/Assignment_05/btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'])

# %%
df.head()
# Out:
#              0            1
# 0  2/4/17 0:00  1099.169125
# 1  3/4/17 0:00  1141.813000
# 2  4/4/17 0:00          NaN
# 3  5/4/17 0:00  1133.079314
# 4  6/4/17 0:00          NaN

# %%
df = pd.read_csv('https://raw.githubusercontent.com/amishraUMBC/690-01/main/Assignment_05/btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'],
                 names=['Timestamp', 'Price'])

# %%
df.head()
# Out:
#      Timestamp        Price
# 0  2/4/17 0:00  1099.169125
# 1  3/4/17 0:00  1141.813000
# 2  4/4/17 0:00          NaN
# 3  5/4/17 0:00  1133.079314
# 4  6/4/17 0:00          NaN

# %%
df = pd.read_csv('https://raw.githubusercontent.com/amishraUMBC/690-01/main/Assignment_05/btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'],
                 names=['Timestamp', 'Price'],
                 dtype={'Price': 'float'})

# %%
df.head()
# Out:
#      Timestamp        Price
# 0  2/4/17 0:00  1099.169125
# 1  3/4/17 0:00  1141.813000
# 2  4/4/17 0:00          NaN
# 3  5/4/17 0:00  1133.079314
# 4  6/4/17 0:00          NaN

# %%
df.dtypes
# Out:
# Timestamp     object
# Price        float64
# dtype: object

# %%
pd.to_datetime(df['Timestamp']).head()
# Out:
# 0   2017-02-04
# 1   2017-03-04
# 2   2017-04-04
# 3   2017-05-04
# 4   2017-06-04
# Name: Timestamp, dtype: datetime64[ns]

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df.head()
# Out:
#    Timestamp        Price
# 0 2017-02-04  1099.169125
# 1 2017-03-04  1141.813000
# 2 2017-04-04          NaN
# 3 2017-05-04  1133.079314
# 4 2017-06-04          NaN

# %%
df.dtypes
# Out:
# Timestamp    datetime64[ns]
# Price               float64
# dtype: object

# %%
df = pd.read_csv('https://raw.githubusercontent.com/amishraUMBC/690-01/main/Assignment_05/btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'],
                 names=['Timestamp', 'Price'],
                 dtype={'Price': 'float'},
                 parse_dates=[0])

# %%
df.head()
# Out:
#    Timestamp        Price
# 0 2017-02-04  1099.169125
# 1 2017-03-04  1141.813000
# 2 2017-04-04          NaN
# 3 2017-05-04  1133.079314
# 4 2017-06-04          NaN
